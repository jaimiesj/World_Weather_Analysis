# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
# Import the requests library.
import requests
# Import the API key.
from config_copy import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        
    
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
#         print(city_url)
#         if i == 17:
#             break

# If an error is experienced, skip the city.
    except Exception as e:
        print("City not found. Skipping...")
        print(e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# 'coord'
# Processing Record 2 of Set 1 | pangnirtung
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | los llanos de aridane
# Processing Record 5 of Set 1 | barbacoas
# Processing Record 6 of Set 1 | deputatskiy
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | anloga
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | hovd
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | tuatapere
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | tezu
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | edea
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | chongwe
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | sistranda
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# 'coord'
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | hambantota
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | koraput
# Processing Record 38 of Set 1 | vanimo
# Processing Record 39 of Set 1 | bubaque
# Processing Record 40 of Set 1 | ahipara
# Processing Record 41 of Set 1 | karasjok
# Processing Record 42 of Set 1 | airai
# Processing Record 43 of Set 1 | sitka
# Processing Record 44 of Set 1 | nago
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | kerema
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | padang
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | kazalinsk
# City not found. Skipping...
# 'coord'
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | fonte boa
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 2 | katobu
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | tateyama
# Processing Record 8 of Set 2 | lasa
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | vao
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | miraflores
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | tarudant
# City not found. Skipping...
# 'coord'
# Processing Record 16 of Set 2 | nuuk
# Processing Record 17 of Set 2 | port hedland
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | myitkyina
# Processing Record 21 of Set 2 | yumen
# Processing Record 22 of Set 2 | tumannyy
# City not found. Skipping...
# 'coord'
# Processing Record 23 of Set 2 | buchanan
# Processing Record 24 of Set 2 | marcona
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | beisfjord
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 2 | abbeville
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | castrillon
# Processing Record 32 of Set 2 | poronaysk
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | okha
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | russell
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | zheleznodorozhnyy
# Processing Record 41 of Set 2 | marsa matruh
# Processing Record 42 of Set 2 | puro
# Processing Record 43 of Set 2 | port lincoln
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | bolungarvik
# City not found. Skipping...
# 'coord'
# Processing Record 46 of Set 2 | buchmany
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | hun
# Processing Record 49 of Set 2 | coquimbo
# Processing Record 50 of Set 2 | burica
# City not found. Skipping...
# 'coord'
# Processing Record 1 of Set 3 | qaqortoq
# Processing Record 2 of Set 3 | alta floresta
# Processing Record 3 of Set 3 | gat
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | lata
# Processing Record 7 of Set 3 | vinh
# Processing Record 8 of Set 3 | kodinsk
# Processing Record 9 of Set 3 | agidel
# Processing Record 10 of Set 3 | banda aceh
# Processing Record 11 of Set 3 | poum
# Processing Record 12 of Set 3 | torbay
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | tapaua
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | mitu
# Processing Record 18 of Set 3 | kazan
# Processing Record 19 of Set 3 | matay
# Processing Record 20 of Set 3 | vadlapudi
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | leua
# Processing Record 23 of Set 3 | horqueta
# Processing Record 24 of Set 3 | turukhansk
# Processing Record 25 of Set 3 | muros
# Processing Record 26 of Set 3 | ketchikan
# Processing Record 27 of Set 3 | alexandria
# Processing Record 28 of Set 3 | vitim
# Processing Record 29 of Set 3 | kysyl-syr
# Processing Record 30 of Set 3 | olga
# Processing Record 31 of Set 3 | huarmey
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | college
# Processing Record 34 of Set 3 | hobart
# Processing Record 35 of Set 3 | koslan
# Processing Record 36 of Set 3 | samoylovka
# Processing Record 37 of Set 3 | todos santos
# Processing Record 38 of Set 3 | hunenberg
# Processing Record 39 of Set 3 | duncan
# Processing Record 40 of Set 3 | la huerta
# Processing Record 41 of Set 3 | cumaribo
# City not found. Skipping...
# 'coord'
# Processing Record 42 of Set 3 | aklavik
# Processing Record 43 of Set 3 | tura
# Processing Record 44 of Set 3 | riacho de santana
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | pichayevo
# Processing Record 47 of Set 3 | belaya gora
# Processing Record 48 of Set 3 | bud
# Processing Record 49 of Set 3 | yerbogachen
# Processing Record 50 of Set 3 | kopanskaya
# Processing Record 1 of Set 4 | longkou
# Processing Record 2 of Set 4 | atar
# Processing Record 3 of Set 4 | hamilton
# Processing Record 4 of Set 4 | kununurra
# Processing Record 5 of Set 4 | sambava
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | saint-philippe
# Processing Record 8 of Set 4 | saleaula
# City not found. Skipping...
# 'coord'
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | longlac
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | olafsvik
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | vardo
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | bossembele
# City not found. Skipping...
# 'coord'
# Processing Record 18 of Set 4 | roma
# Processing Record 19 of Set 4 | juneau
# Processing Record 20 of Set 4 | tessalit
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | lagoa formosa
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 4 | cockburn town
# Processing Record 26 of Set 4 | gimli
# Processing Record 27 of Set 4 | nizhneyansk
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 4 | uray
# Processing Record 29 of Set 4 | veliki preslav
# Processing Record 30 of Set 4 | ambodifototra
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 4 | harindanga
# Processing Record 32 of Set 4 | udachnyy
# Processing Record 33 of Set 4 | san cristobal
# Processing Record 34 of Set 4 | luanda
# Processing Record 35 of Set 4 | nizwa
# Processing Record 36 of Set 4 | hailar
# Processing Record 37 of Set 4 | alyangula
# Processing Record 38 of Set 4 | saint-pierre
# Processing Record 39 of Set 4 | ahuimanu
# Processing Record 40 of Set 4 | sola
# Processing Record 41 of Set 4 | port macquarie
# Processing Record 42 of Set 4 | luau
# Processing Record 43 of Set 4 | konevo
# Processing Record 44 of Set 4 | launceston
# Processing Record 45 of Set 4 | cidreira
# Processing Record 46 of Set 4 | roald
# Processing Record 47 of Set 4 | avera
# Processing Record 48 of Set 4 | saryagash
# Processing Record 49 of Set 4 | sulangan
# Processing Record 50 of Set 4 | ostrovnoy
# Processing Record 1 of Set 5 | tautira
# Processing Record 2 of Set 5 | sisophon
# Processing Record 3 of Set 5 | makat
# Processing Record 4 of Set 5 | palabuhanratu
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 5 | mount gambier
# Processing Record 6 of Set 5 | ombessa
# Processing Record 7 of Set 5 | longyearbyen
# Processing Record 8 of Set 5 | ouallam
# Processing Record 9 of Set 5 | hermanus
# Processing Record 10 of Set 5 | kushiro
# Processing Record 11 of Set 5 | erenhot
# Processing Record 12 of Set 5 | sur
# Processing Record 13 of Set 5 | aksarka
# Processing Record 14 of Set 5 | sukumo
# Processing Record 15 of Set 5 | grand river south east
# City not found. Skipping...
# 'coord'
# Processing Record 16 of Set 5 | marivan
# Processing Record 17 of Set 5 | saldanha
# Processing Record 18 of Set 5 | meulaboh
# Processing Record 19 of Set 5 | guasdualito
# Processing Record 20 of Set 5 | mezen
# Processing Record 21 of Set 5 | kushmurun
# Processing Record 22 of Set 5 | naze
# Processing Record 23 of Set 5 | dingle
# Processing Record 24 of Set 5 | narsaq
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | salaya
# Processing Record 27 of Set 5 | deer lake
# Processing Record 28 of Set 5 | oranjemund
# Processing Record 29 of Set 5 | kihei
# Processing Record 30 of Set 5 | la ronge
# Processing Record 31 of Set 5 | thunder bay
# Processing Record 32 of Set 5 | faanui
# Processing Record 33 of Set 5 | abu jubayhah
# City not found. Skipping...
# 'coord'
# Processing Record 34 of Set 5 | haines junction
# Processing Record 35 of Set 5 | aniva
# Processing Record 36 of Set 5 | louis trichardt
# Processing Record 37 of Set 5 | kourou
# Processing Record 38 of Set 5 | mogok
# Processing Record 39 of Set 5 | iqaluit
# Processing Record 40 of Set 5 | lebu
# Processing Record 41 of Set 5 | hualmay
# Processing Record 42 of Set 5 | wanning
# Processing Record 43 of Set 5 | gamba
# Processing Record 44 of Set 5 | andros town
# Processing Record 45 of Set 5 | tsihombe
# City not found. Skipping...
# 'coord'
# Processing Record 46 of Set 5 | victoria
# Processing Record 47 of Set 5 | barcelos
# Processing Record 48 of Set 5 | diapaga
# Processing Record 49 of Set 5 | mehamn
# Processing Record 50 of Set 5 | warqla
# City not found. Skipping...
# 'coord'
# Processing Record 1 of Set 6 | barahona
# Processing Record 2 of Set 6 | manthani
# Processing Record 3 of Set 6 | razole
# Processing Record 4 of Set 6 | pemangkat
# Processing Record 5 of Set 6 | svencionys
# Processing Record 6 of Set 6 | aksay
# Processing Record 7 of Set 6 | tucumcari
# Processing Record 8 of Set 6 | lavrentiya
# Processing Record 9 of Set 6 | koroni
# Processing Record 10 of Set 6 | ancud
# Processing Record 11 of Set 6 | katsuura
# Processing Record 12 of Set 6 | frontera
# Processing Record 13 of Set 6 | tamandare
# Processing Record 14 of Set 6 | mangaluru
# Processing Record 15 of Set 6 | asau
# Processing Record 16 of Set 6 | saint-francois
# Processing Record 17 of Set 6 | riyadh
# Processing Record 18 of Set 6 | umm lajj
# Processing Record 19 of Set 6 | weihai
# Processing Record 20 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# 'coord'
# Processing Record 21 of Set 6 | anadyr
# Processing Record 22 of Set 6 | mayumba
# Processing Record 23 of Set 6 | beringovskiy
# Processing Record 24 of Set 6 | baykit
# Processing Record 25 of Set 6 | tocache
# Processing Record 26 of Set 6 | cacimba de dentro
# Processing Record 27 of Set 6 | moose factory
# Processing Record 28 of Set 6 | valle hermoso
# Processing Record 29 of Set 6 | portland
# Processing Record 30 of Set 6 | raudeberg
# Processing Record 31 of Set 6 | umzimvubu
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 6 | touros
# Processing Record 33 of Set 6 | maroantsetra
# Processing Record 34 of Set 6 | guerrero negro
# Processing Record 35 of Set 6 | coahuayana
# Processing Record 36 of Set 6 | ambon
# Processing Record 37 of Set 6 | puli
# Processing Record 38 of Set 6 | pervoye maya
# Processing Record 39 of Set 6 | searcy
# Processing Record 40 of Set 6 | maracaju
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | kozhva
# Processing Record 43 of Set 6 | pisco
# Processing Record 44 of Set 6 | taungdwingyi
# Processing Record 45 of Set 6 | ostersund
# Processing Record 46 of Set 6 | bucerias
# Processing Record 47 of Set 6 | ye
# City not found. Skipping...
# 'coord'
# Processing Record 48 of Set 6 | fuerte olimpo
# Processing Record 49 of Set 6 | gangotri
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 6 | balurghat
# Processing Record 1 of Set 7 | mandan
# Processing Record 2 of Set 7 | san vicente
# Processing Record 3 of Set 7 | bogorodskoye
# Processing Record 4 of Set 7 | sechenovo
# Processing Record 5 of Set 7 | bambous virieux
# Processing Record 6 of Set 7 | tanout
# Processing Record 7 of Set 7 | maniwaki
# Processing Record 8 of Set 7 | kupang
# Processing Record 9 of Set 7 | kalach-na-donu
# Processing Record 10 of Set 7 | yining
# Processing Record 11 of Set 7 | abu samrah
# Processing Record 12 of Set 7 | columbus
# Processing Record 13 of Set 7 | saint george
# Processing Record 14 of Set 7 | jacareacanga
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | luderitz
# Processing Record 17 of Set 7 | peace river
# Processing Record 18 of Set 7 | meyungs
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 7 | tieling
# Processing Record 20 of Set 7 | hohhot
# Processing Record 21 of Set 7 | pringsewu
# Processing Record 22 of Set 7 | kudahuvadhoo
# Processing Record 23 of Set 7 | benjamin hill
# Processing Record 24 of Set 7 | pacific grove
# Processing Record 25 of Set 7 | madingou
# Processing Record 26 of Set 7 | kamenka
# Processing Record 27 of Set 7 | eyl
# Processing Record 28 of Set 7 | taoudenni
# Processing Record 29 of Set 7 | rockport
# Processing Record 30 of Set 7 | ji-parana
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 7 | lompoc
# Processing Record 32 of Set 7 | chilca
# Processing Record 33 of Set 7 | benito juarez
# Processing Record 34 of Set 7 | belyy yar
# Processing Record 35 of Set 7 | saint-ambroise
# Processing Record 36 of Set 7 | san luis
# Processing Record 37 of Set 7 | koutsouras
# Processing Record 38 of Set 7 | purpe
# Processing Record 39 of Set 7 | rengo
# Processing Record 40 of Set 7 | maues
# Processing Record 41 of Set 7 | hanzhong
# Processing Record 42 of Set 7 | winchester
# Processing Record 43 of Set 7 | labuhan
# Processing Record 44 of Set 7 | meghri
# Processing Record 45 of Set 7 | sena madureira
# Processing Record 46 of Set 7 | upernavik
# Processing Record 47 of Set 7 | ekibastuz
# Processing Record 48 of Set 7 | tabarqah
# City not found. Skipping...
# 'coord'
# Processing Record 49 of Set 7 | campbell river
# Processing Record 50 of Set 7 | goderich
# Processing Record 1 of Set 8 | girua
# Processing Record 2 of Set 8 | samusu
# City not found. Skipping...
# 'coord'
# Processing Record 3 of Set 8 | flinders
# Processing Record 4 of Set 8 | hudson bay
# Processing Record 5 of Set 8 | lagoa
# Processing Record 6 of Set 8 | mareeba
# Processing Record 7 of Set 8 | igualada
# Processing Record 8 of Set 8 | puerto penasco
# Processing Record 9 of Set 8 | moroni
# Processing Record 10 of Set 8 | westport
# Processing Record 11 of Set 8 | khonsa
# Processing Record 12 of Set 8 | lumeje
# Processing Record 13 of Set 8 | adelaide
# Processing Record 14 of Set 8 | hofn
# Processing Record 15 of Set 8 | sao filipe
# Processing Record 16 of Set 8 | bridlington
# Processing Record 17 of Set 8 | maceio
# Processing Record 18 of Set 8 | gravdal
# Processing Record 19 of Set 8 | vestmannaeyjar
# Processing Record 20 of Set 8 | karratha
# Processing Record 21 of Set 8 | del rio
# Processing Record 22 of Set 8 | jalu
# Processing Record 23 of Set 8 | vernon
# Processing Record 24 of Set 8 | dauriya
# Processing Record 25 of Set 8 | west odessa
# Processing Record 26 of Set 8 | leningradskiy
# Processing Record 27 of Set 8 | simav
# Processing Record 28 of Set 8 | semporna
# Processing Record 29 of Set 8 | khandyga
# Processing Record 30 of Set 8 | esperance
# Processing Record 31 of Set 8 | weston-super-mare
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | nanortalik
# Processing Record 34 of Set 8 | arkhipo-osipovka
# Processing Record 35 of Set 8 | wenling
# Processing Record 36 of Set 8 | acarau
# Processing Record 37 of Set 8 | sept-iles
# Processing Record 38 of Set 8 | caravelas
# Processing Record 39 of Set 8 | kralendijk
# Processing Record 40 of Set 8 | ust-nera
# Processing Record 41 of Set 8 | nemuro
# Processing Record 42 of Set 8 | matara
# Processing Record 43 of Set 8 | maniitsoq
# Processing Record 44 of Set 8 | northam
# Processing Record 45 of Set 8 | byron bay
# Processing Record 46 of Set 8 | kruisfontein
# Processing Record 47 of Set 8 | tapes
# Processing Record 48 of Set 8 | atambua
# Processing Record 49 of Set 8 | kahului
# Processing Record 50 of Set 8 | vittoria
# Processing Record 1 of Set 9 | port keats
# Processing Record 2 of Set 9 | vaitupu
# City not found. Skipping...
# 'coord'
# Processing Record 3 of Set 9 | oktyabrskiy
# Processing Record 4 of Set 9 | ruatoria
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 9 | boende
# Processing Record 6 of Set 9 | vagay
# Processing Record 7 of Set 9 | sawang daen din
# Processing Record 8 of Set 9 | tacuarembo
# Processing Record 9 of Set 9 | tawkar
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 9 | manaus
# Processing Record 11 of Set 9 | kananga
# Processing Record 12 of Set 9 | husavik
# Processing Record 13 of Set 9 | richard toll
# City not found. Skipping...
# 'coord'
# Processing Record 14 of Set 9 | eston
# Processing Record 15 of Set 9 | inongo
# Processing Record 16 of Set 9 | provideniya
# Processing Record 17 of Set 9 | sassandra
# Processing Record 18 of Set 9 | nuevo progreso
# Processing Record 19 of Set 9 | pangody
# Processing Record 20 of Set 9 | nouadhibou
# Processing Record 21 of Set 9 | anchorage
# Processing Record 22 of Set 9 | asfi
# Processing Record 23 of Set 9 | erzin
# Processing Record 24 of Set 9 | yarada
# Processing Record 25 of Set 9 | boa vista
# Processing Record 26 of Set 9 | scottsboro
# Processing Record 27 of Set 9 | nhulunbuy
# Processing Record 28 of Set 9 | tiznit
# Processing Record 29 of Set 9 | charters towers
# Processing Record 30 of Set 9 | zdvinsk
# Processing Record 31 of Set 9 | paamiut
# Processing Record 32 of Set 9 | shabqadar
# Processing Record 33 of Set 9 | finschhafen
# Processing Record 34 of Set 9 | whitianga
# Processing Record 35 of Set 9 | saryshagan
# City not found. Skipping...
# 'coord'
# Processing Record 36 of Set 9 | xingcheng
# Processing Record 37 of Set 9 | talcahuano
# Processing Record 38 of Set 9 | ambulu
# Processing Record 39 of Set 9 | bandar-e lengeh
# Processing Record 40 of Set 9 | petrozavodsk
# Processing Record 41 of Set 9 | umm kaddadah
# Processing Record 42 of Set 9 | san policarpo
# Processing Record 43 of Set 9 | iquique
# Processing Record 44 of Set 9 | tarifa
# Processing Record 45 of Set 9 | vega de alatorre
# Processing Record 46 of Set 9 | yar-sale
# Processing Record 47 of Set 9 | mahanoro
# Processing Record 48 of Set 9 | valdivia
# Processing Record 49 of Set 9 | kamenskoye
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 9 | aykhal
# Processing Record 1 of Set 10 | camargo
# Processing Record 2 of Set 10 | takab
# Processing Record 3 of Set 10 | kavaratti
# Processing Record 4 of Set 10 | kaeng khoi
# Processing Record 5 of Set 10 | kushima
# Processing Record 6 of Set 10 | arlit
# Processing Record 7 of Set 10 | shache
# Processing Record 8 of Set 10 | zhigansk
# Processing Record 9 of Set 10 | barbar
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 10 | karatau
# Processing Record 11 of Set 10 | ukiah
# Processing Record 12 of Set 10 | bowen
# Processing Record 13 of Set 10 | havre-saint-pierre
# Processing Record 14 of Set 10 | belushya guba
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 10 | taltal
# Processing Record 16 of Set 10 | antofagasta
# Processing Record 17 of Set 10 | illapel
# Processing Record 18 of Set 10 | mandalgovi
# Processing Record 19 of Set 10 | havoysund
# Processing Record 20 of Set 10 | hirara
# Processing Record 21 of Set 10 | cherskiy
# Processing Record 22 of Set 10 | porto novo
# Processing Record 23 of Set 10 | wamba
# Processing Record 24 of Set 10 | harlingen
# Processing Record 25 of Set 10 | fasa
# Processing Record 26 of Set 10 | broome
# Processing Record 27 of Set 10 | ossora
# Processing Record 28 of Set 10 | san quintin
# Processing Record 29 of Set 10 | bengkulu
# Processing Record 30 of Set 10 | manhattan
# Processing Record 31 of Set 10 | yatou
# Processing Record 32 of Set 10 | faya
# Processing Record 33 of Set 10 | egvekinot
# Processing Record 34 of Set 10 | san carlos
# Processing Record 35 of Set 10 | weatherford
# City not found. Skipping...
# ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Processing Record 36 of Set 10 | north bend
# Processing Record 37 of Set 10 | kathu
# Processing Record 38 of Set 10 | labelle
# Processing Record 39 of Set 10 | lakhnau
# Processing Record 40 of Set 10 | chapais
# Processing Record 41 of Set 10 | kurmanayevka
# Processing Record 42 of Set 10 | plainview
# Processing Record 43 of Set 10 | nova mayachka
# Processing Record 44 of Set 10 | pandan
# Processing Record 45 of Set 10 | hihifo
# City not found. Skipping...
# 'coord'
# Processing Record 46 of Set 10 | leshukonskoye
# Processing Record 47 of Set 10 | sioux lookout
# Processing Record 48 of Set 10 | pontianak
# Processing Record 49 of Set 10 | angoche
# Processing Record 50 of Set 10 | tabiauea
# City not found. Skipping...
# 'coord'
# Processing Record 1 of Set 11 | doha
# Processing Record 2 of Set 11 | abay
# Processing Record 3 of Set 11 | carmelo
# Processing Record 4 of Set 11 | mbandaka
# Processing Record 5 of Set 11 | dire
# Processing Record 6 of Set 11 | cabedelo
# Processing Record 7 of Set 11 | camacha
# Processing Record 8 of Set 11 | mlonggo
# Processing Record 9 of Set 11 | lolua
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 11 | porteirinha
# Processing Record 11 of Set 11 | vila franca do campo
# Processing Record 12 of Set 11 | ambatofinandrahana
# Processing Record 13 of Set 11 | sentyabrskiy
# City not found. Skipping...
# 'coord'
# Processing Record 14 of Set 11 | obregon
# Processing Record 15 of Set 11 | nazilli
# Processing Record 16 of Set 11 | ust-kuyga
# Processing Record 17 of Set 11 | alingsas
# Processing Record 18 of Set 11 | waw
# Processing Record 19 of Set 11 | tiarei
# Processing Record 20 of Set 11 | requena
# Processing Record 21 of Set 11 | abiy adi
# City not found. Skipping...
# 'coord'
# Processing Record 22 of Set 11 | komatipoort
# Processing Record 23 of Set 11 | mortka
# Processing Record 24 of Set 11 | talaya
# Processing Record 25 of Set 11 | santiago del estero
# Processing Record 26 of Set 11 | ugoofaaru
# Processing Record 27 of Set 11 | tahta
# Processing Record 28 of Set 11 | grand gaube
# Processing Record 29 of Set 11 | prince rupert
# Processing Record 30 of Set 11 | goregaon
# Processing Record 31 of Set 11 | ordu
# Processing Record 32 of Set 11 | dicabisagan
# Processing Record 33 of Set 11 | garoua boulai
# Processing Record 34 of Set 11 | coolum beach
# Processing Record 35 of Set 11 | shimoda
# Processing Record 36 of Set 11 | tuggurt
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 11 | kanigiri
# Processing Record 38 of Set 11 | bonavista
# Processing Record 39 of Set 11 | loma bonita
# Processing Record 40 of Set 11 | atherton
# Processing Record 41 of Set 11 | jiangyou
# Processing Record 42 of Set 11 | bousso
# Processing Record 43 of Set 11 | vieques
# Processing Record 44 of Set 11 | luena
# Processing Record 45 of Set 11 | berlevag
# Processing Record 46 of Set 11 | laguna
# Processing Record 47 of Set 11 | rumuruti
# Processing Record 48 of Set 11 | waiouru
# Processing Record 49 of Set 11 | yablonovo
# Processing Record 50 of Set 11 | sidhi
# Processing Record 1 of Set 12 | pengcheng
# Processing Record 2 of Set 12 | shar
# Processing Record 3 of Set 12 | teguise
# Processing Record 4 of Set 12 | thohoyandou
# Processing Record 5 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 12 | lodja
# Processing Record 7 of Set 12 | ibimirim
# Processing Record 8 of Set 12 | ardakan
# Processing Record 9 of Set 12 | balabac
# Processing Record 10 of Set 12 | ormara
# Processing Record 11 of Set 12 | basoko
# Processing Record 12 of Set 12 | henties bay
# Processing Record 13 of Set 12 | yei
# Processing Record 14 of Set 12 | kashi
# Processing Record 15 of Set 12 | itarema
# Processing Record 16 of Set 12 | fairbanks
# Processing Record 17 of Set 12 | phonhong
# Processing Record 18 of Set 12 | shahr-e babak
# Processing Record 19 of Set 12 | ravar
# Processing Record 20 of Set 12 | shakawe
# Processing Record 21 of Set 12 | srednekolymsk
# Processing Record 22 of Set 12 | vanavara
# Processing Record 23 of Set 12 | sakakah
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | mackenzie
# Processing Record 26 of Set 12 | awbari
# Processing Record 27 of Set 12 | sayyan
# Processing Record 28 of Set 12 | te anau
# Processing Record 29 of Set 12 | dukat
# Processing Record 30 of Set 12 | tucuman
# Processing Record 31 of Set 12 | fountain hills
# Processing Record 32 of Set 12 | casambalangan
# Processing Record 33 of Set 12 | fort nelson
# Processing Record 34 of Set 12 | alihe
# Processing Record 35 of Set 12 | zaragoza
# Processing Record 36 of Set 12 | souillac
# Processing Record 37 of Set 12 | visimo-utkinsk
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 12 | port hueneme
# Processing Record 39 of Set 12 | saint-augustin
# Processing Record 40 of Set 12 | monkey bay
# Processing Record 41 of Set 12 | nome
# Processing Record 42 of Set 12 | kismayo
# Processing Record 43 of Set 12 | mana
# Processing Record 44 of Set 12 | coaticook
# Processing Record 45 of Set 12 | vila
# Processing Record 46 of Set 12 | temaraia
# City not found. Skipping...
# 'coord'
# Processing Record 47 of Set 12 | minas
# Processing Record 48 of Set 12 | nyimba
# Processing Record 49 of Set 12 | kadykchan
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 12 | klaksvik
# Processing Record 1 of Set 13 | gasa
# Processing Record 2 of Set 13 | severodvinsk
# Processing Record 3 of Set 13 | axim
# Processing Record 4 of Set 13 | maykain
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 13 | tahe
# Processing Record 6 of Set 13 | seoul
# Processing Record 7 of Set 13 | sabang
# Processing Record 8 of Set 13 | muyezerskiy
# Processing Record 9 of Set 13 | yinchuan
# Processing Record 10 of Set 13 | khasan
# Processing Record 11 of Set 13 | laizhou
# Processing Record 12 of Set 13 | terney
# Processing Record 13 of Set 13 | barra patuca
# Processing Record 14 of Set 13 | port hardy
# Processing Record 15 of Set 13 | shihezi
# Processing Record 16 of Set 13 | viytivka
# Processing Record 17 of Set 13 | rawson
# Processing Record 18 of Set 13 | sangmelima
# Processing Record 19 of Set 13 | lakatoro
# Processing Record 20 of Set 13 | morwell
# Processing Record 21 of Set 13 | pauini
# Processing Record 22 of Set 13 | trincomalee
# Processing Record 23 of Set 13 | lafiagi
# Processing Record 24 of Set 13 | rawicz
# Processing Record 25 of Set 13 | batemans bay
# Processing Record 26 of Set 13 | kristinehamn
# Processing Record 27 of Set 13 | isangel
# Processing Record 28 of Set 13 | samarai
# Processing Record 29 of Set 13 | stege
# Processing Record 30 of Set 13 | aginskoye
# Processing Record 31 of Set 13 | myanaung
# Processing Record 32 of Set 13 | carikar
# City not found. Skipping...
# 'coord'
# Processing Record 33 of Set 13 | zhangye
# Processing Record 34 of Set 13 | bonthe
# Processing Record 35 of Set 13 | wakema
# Processing Record 36 of Set 13 | sidvokodvo
# Processing Record 37 of Set 13 | toliary
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 13 | tome-acu
# City not found. Skipping...
# 'coord'
# Processing Record 39 of Set 13 | alofi
# Processing Record 40 of Set 13 | nanakuli
# Processing Record 41 of Set 13 | liverpool
# Processing Record 42 of Set 13 | dzerzhinsk
# Processing Record 43 of Set 13 | nefteyugansk
# Processing Record 44 of Set 13 | along
# Processing Record 45 of Set 13 | boddam
# Processing Record 46 of Set 13 | fagernes
# Processing Record 47 of Set 13 | orito
# Processing Record 48 of Set 13 | biak
# Processing Record 49 of Set 13 | nikki
# Processing Record 50 of Set 13 | mbaiki
# Processing Record 1 of Set 14 | fayaoue
# Processing Record 2 of Set 14 | samarinda
# Processing Record 3 of Set 14 | ituverava
# Processing Record 4 of Set 14 | linhares
# Processing Record 5 of Set 14 | tommot
# Processing Record 6 of Set 14 | whitehorse
# Processing Record 7 of Set 14 | oussouye
# Processing Record 8 of Set 14 | lensk
# Processing Record 9 of Set 14 | dustlik
# Processing Record 10 of Set 14 | koumac
# Processing Record 11 of Set 14 | manono
# Processing Record 12 of Set 14 | rio grande
# Processing Record 13 of Set 14 | nizhnevartovsk
# Processing Record 14 of Set 14 | chagda
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 14 | puerto colombia
# Processing Record 16 of Set 14 | nantucket
# Processing Record 17 of Set 14 | namibe
# Processing Record 18 of Set 14 | coihaique
# Processing Record 19 of Set 14 | gazanjyk
# Processing Record 20 of Set 14 | mineiros
# Processing Record 21 of Set 14 | sidney
# Processing Record 22 of Set 14 | finnsnes
# Processing Record 23 of Set 14 | benguela
# Processing Record 24 of Set 14 | tasbuget
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 14 | gigmoto
# Processing Record 26 of Set 14 | xuddur
# Processing Record 27 of Set 14 | longhua
# Processing Record 28 of Set 14 | louisbourg
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 14 | le gosier
# Processing Record 30 of Set 14 | tortoli
# Processing Record 31 of Set 14 | margate
# Processing Record 32 of Set 14 | manicore
# Processing Record 33 of Set 14 | tulare
# Processing Record 34 of Set 14 | synya
# Processing Record 35 of Set 14 | ambunti
# Processing Record 36 of Set 14 | urambo
# Processing Record 37 of Set 14 | atasu
# Processing Record 38 of Set 14 | necochea
# Processing Record 39 of Set 14 | grand island
# Processing Record 40 of Set 14 | gornyy
# Processing Record 41 of Set 14 | kedrovyy
# Processing Record 42 of Set 14 | martapura
# Processing Record 43 of Set 14 | warrnambool
# Processing Record 44 of Set 14 | sumbawa
# City not found. Skipping...
# 'coord'
# Processing Record 45 of Set 14 | ituni
# City not found. Skipping...
# 'coord'
# Processing Record 46 of Set 14 | xiongyue
# Processing Record 47 of Set 14 | las vegas
# Processing Record 48 of Set 14 | acapulco
# Processing Record 49 of Set 14 | juegang
# Processing Record 50 of Set 14 | ina
# Processing Record 1 of Set 15 | gizo
# Processing Record 2 of Set 15 | tabora
# Processing Record 3 of Set 15 | bandundu
# Processing Record 4 of Set 15 | singaraja
# Processing Record 5 of Set 15 | kang
# Processing Record 6 of Set 15 | semey
# Processing Record 7 of Set 15 | tignere
# Processing Record 8 of Set 15 | pokrovskoye
# Processing Record 9 of Set 15 | filingue
# Processing Record 10 of Set 15 | bafq
# Processing Record 11 of Set 15 | sawtell
# Processing Record 12 of Set 15 | ginda
# Processing Record 13 of Set 15 | hearst
# Processing Record 14 of Set 15 | solana beach
# Processing Record 15 of Set 15 | gilbues
# Processing Record 16 of Set 15 | creel
# Processing Record 17 of Set 15 | dalnegorsk
# Processing Record 18 of Set 15 | izhma
# Processing Record 19 of Set 15 | kuche
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 15 | daru
# Processing Record 21 of Set 15 | verkhoyansk
# Processing Record 22 of Set 15 | progreso
# Processing Record 23 of Set 15 | bara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Pangnirtung  66.1451  -65.7125     33.80        64          75
# 1                Ushuaia -54.8000  -68.3000     40.66        56          75
# 2  Los Llanos De Aridane  28.6585  -17.9182     73.15        77          75
# 3              Barbacoas   1.6715  -78.1398     80.83        83          71
# 4            Deputatskiy  69.3000  139.9000     26.46        86         100
# 5                 Castro -24.7911  -50.0119     72.36        54          12
# 6                Rikitea -23.1203 -134.9692     73.78        73          15
# 7              Jamestown  42.0970  -79.2353     62.51        72           1
# 8                Kavieng  -2.5744  150.7967     82.33        78           9
# 9           Puerto Ayora  -0.7393  -90.3518     71.56        87          99
#
#    Wind Speed Country Current Description
# 0        3.44      CA       broken clouds
# 1       12.66      AR       broken clouds
# 2        6.91      ES        volcanic ash
# 3        1.72      CO       broken clouds
# 4       16.33      RU     overcast clouds
# 5        3.42      BR          few clouds
# 6       14.94      PF          few clouds
# 7        5.01      US           clear sky
# 8       15.08      PG           clear sky
# 9        8.57      EC     overcast clouds

# %%
#reorder the columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Pangnirtung      CA  66.1451  -65.7125     33.80        64
# 1                  Ushuaia      AR -54.8000  -68.3000     40.66        56
# 2    Los Llanos De Aridane      ES  28.6585  -17.9182     73.15        77
# 3                Barbacoas      CO   1.6715  -78.1398     80.83        83
# 4              Deputatskiy      RU  69.3000  139.9000     26.46        86
# ..                     ...     ...      ...       ...       ...       ...
# 658                  Izhma      RU  65.0083   53.9113     47.46        77
# 659                   Daru      PG  -9.0763  143.2092     76.89        93
# 660            Verkhoyansk      RU  67.5447  133.3850     35.82        72
# 661               Progreso      MX  21.2833  -89.6667     82.11        68
# 662                   Bara      NG  10.3744   10.7288     90.93        43
#
#      Cloudiness  Wind Speed Current Description
# 0            75        3.44       broken clouds
# 1            75       12.66       broken clouds
# 2            75        6.91        volcanic ash
# 3            71        1.72       broken clouds
# 4           100       16.33     overcast clouds
# ..          ...         ...                 ...
# 658         100       13.06     overcast clouds
# 659          99       14.29     overcast clouds
# 660         100        3.15     overcast clouds
# 661          13        4.07          few clouds
# 662          33        2.73    scattered clouds
#
# [663 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
